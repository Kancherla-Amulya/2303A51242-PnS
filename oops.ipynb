# %% [markdown]
# <a href="https://colab.research.google.com/github/Kancherla-Amulya/2303A51242-PnS/blob/main/oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class contract_based:
  def contract_employees(self):
    print("contract employees")
class accenture(contract_based):
  def employees(self):
    print("accenture employees")
employee1 = accenture()
employee1.employees()
employee1.contract_employees()
# Out:
# accenture employees
# contract employees
