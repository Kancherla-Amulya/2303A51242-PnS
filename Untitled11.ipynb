# %% [markdown]
# <a href="https://colab.research.google.com/github/Kancherla-Amulya/2303A51242-PnS/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
correlation_matrix = np.corrcoef(X, Y)
correlation_coefficient = correlation_matrix[0, 1]
print("Correlation Coefficient:", correlation_coefficient)
x = [10, 15, 20, 25, 30, 35]
y = [68, 60, 55, 48, 38, 32]
plt.scatter(x, y, color='purple')
plt.title('Scatter Plot of Price vs Number of Pens Sold')
plt.xlabel('Price')
plt.ylabel('Number of Pens Sold')
plt.grid(True)
plt.show()
# Out:
# Correlation Coefficient: -0.9965084488144091
